# %%
import json

# %%
data = """{"version":2,"www":"erdplus.com","shapes":[{"type":"Entity","details":{"name":"Flight","type":"regular","x":624,"y":128,"isDisjointed":true,"isTotalSpecialization":true,"isSubtype":false,"supertypeEntityId":null,"id":1}},{"type":"Attribute","details":{"name":"Source Airport ID","isDerived":false,"isMultivalued":false,"isOptional":false,"isComposite":false,"isUnique":false,"x":376,"y":98,"id":2}},{"type":"Attribute","details":{"name":"Destination Airport ID","isDerived":false,"isMultivalued":false,"isOptional":false,"isComposite":false,"isUnique":false,"x":422,"y":43,"id":4}},{"type":"Attribute","details":{"name":"Departure Time","isDerived":false,"isMultivalued":false,"isOptional":false,"isComposite":false,"isUnique":false,"x":529,"y":31,"id":6}},{"type":"Attribute","details":{"name":"Arrival Time","isDerived":false,"isMultivalued":false,"isOptional":false,"isComposite":false,"isUnique":false,"x":861,"y":61,"id":8}},{"type":"Attribute","details":{"name":"Aircraft ID","isDerived":false,"isMultivalued":false,"isOptional":false,"isComposite":false,"isUnique":false,"x":751,"y":37,"id":10}},{"type":"Entity","details":{"name":"Aircraft","type":"regular","x":1237,"y":129.5,"isDisjointed":true,"isTotalSpecialization":true,"isSubtype":false,"supertypeEntityId":null,"id":14}},{"type":"Attribute","details":{"name":"Aircraft Type","isDerived":false,"isMultivalued":false,"isOptional":false,"isComposite":false,"isUnique":false,"x":1201,"y":39.5,"id":15}},{"type":"Attribute","details":{"name":"Current Status","isDerived":false,"isMultivalued":false,"isOptional":false,"isComposite":false,"isUnique":false,"x":1314,"y":44.5,"id":17}},{"type":"Relationship","details":{"name":"Assigned To Flight","isIdentifying":false,"x":1000,"y":87,"slots":[{"slotIndex":0,"minimum":"","maximum":"","participation":"mandatory","cardinality":"one","role":"","entityId":14},{"slotIndex":1,"minimum":"","maximum":"","participation":"mandatory","cardinality":"one","role":"","entityId":1}],"id":19}},{"type":"Entity","details":{"name":"Crew","type":"regular","x":146,"y":180.5,"isDisjointed":true,"isTotalSpecialization":true,"isSubtype":false,"supertypeEntityId":null,"id":22}},{"type":"Attribute","details":{"name":"Crew Type","isDerived":false,"isMultivalued":false,"isOptional":false,"isComposite":false,"isUnique":false,"x":88,"y":104.5,"id":23}},{"type":"Attribute","details":{"name":"Member Name","isDerived":false,"isMultivalued":false,"isOptional":false,"isComposite":false,"isUnique":false,"x":151,"y":260.5,"id":25}},{"type":"Entity","details":{"name":"Gate","type":"regular","x":123,"y":500.5,"isDisjointed":true,"isTotalSpecialization":true,"isSubtype":false,"supertypeEntityId":null,"id":27}},{"type":"Attribute","details":{"name":"Terminal Name","isDerived":false,"isMultivalued":false,"isOptional":false,"isComposite":false,"isUnique":false,"x":80,"y":402.5,"id":28}},{"type":"Attribute","details":{"name":"Gate Number","isDerived":false,"isMultivalued":false,"isOptional":false,"isComposite":false,"isUnique":false,"x":74,"y":586.5,"id":30}},{"type":"Relationship","details":{"name":"Flight_Crew","isIdentifying":false,"x":315,"y":169,"slots":[{"slotIndex":0,"minimum":"","maximum":"","participation":"mandatory","cardinality":"many","role":"","entityId":1},{"slotIndex":1,"minimum":"","maximum":"","participation":"mandatory","cardinality":"many","role":"","entityId":22}],"id":32}},{"type":"Relationship","details":{"name":"Arrival_Gate","isIdentifying":false,"x":354,"y":278,"slots":[{"slotIndex":0,"minimum":"","maximum":"","participation":"mandatory","cardinality":"one","role":"","entityId":1},{"slotIndex":1,"minimum":"","maximum":"","participation":"optional","cardinality":"many","role":"","entityId":27}],"id":35}},{"type":"Entity","details":{"name":"Passenger","type":"regular","x":1299,"y":295.5,"isDisjointed":true,"isTotalSpecialization":true,"isSubtype":false,"supertypeEntityId":null,"id":41}},{"type":"Attribute","details":{"name":"Name","isDerived":false,"isMultivalued":false,"isOptional":false,"isComposite":false,"isUnique":false,"x":1455,"y":307.5,"id":42}},{"type":"Attribute","details":{"name":"Ticket Number","isDerived":false,"isMultivalued":false,"isOptional":false,"isComposite":false,"isUnique":false,"x":1449,"y":237.5,"id":44}},{"type":"Attribute","details":{"name":"Flight Number","isDerived":false,"isMultivalued":false,"isOptional":false,"isComposite":false,"isUnique":false,"x":1340,"y":200.5,"id":46}},{"type":"Attribute","details":{"name":"Connecting Flight Number","isDerived":false,"isMultivalued":false,"isOptional":false,"isComposite":false,"isUnique":false,"x":1411,"y":367.5,"id":48}},{"type":"Relationship","details":{"name":"Passengers Flight","isIdentifying":false,"x":928,"y":208,"slots":[{"slotIndex":0,"minimum":"","maximum":"","participation":"optional","cardinality":"one","role":"","entityId":1},{"slotIndex":1,"minimum":"","maximum":"","participation":"mandatory","cardinality":"many","role":"","entityId":41}],"id":66}},{"type":"Entity","details":{"name":"Weather","type":"regular","x":1220,"y":528.5,"isDisjointed":true,"isTotalSpecialization":true,"isSubtype":false,"supertypeEntityId":null,"id":69}},{"type":"Attribute","details":{"name":"Conditions","isDerived":false,"isMultivalued":false,"isOptional":false,"isComposite":false,"isUnique":false,"x":1386,"y":595.5,"id":70}},{"type":"Attribute","details":{"name":"Source Airport","isDerived":false,"isMultivalued":false,"isOptional":false,"isComposite":false,"isUnique":false,"x":1379,"y":459.5,"id":72}},{"type":"Attribute","details":{"name":"Destination Airport","isDerived":false,"isMultivalued":false,"isOptional":false,"isComposite":false,"isUnique":false,"x":1393,"y":539.5,"id":74}},{"type":"Attribute","details":{"name":"Update Time","isDerived":false,"isMultivalued":false,"isOptional":false,"isComposite":false,"isUnique":false,"x":1249,"y":622.5,"id":78}},{"type":"Relationship","details":{"name":"Current Weather","isIdentifying":false,"x":919,"y":317,"slots":[{"slotIndex":0,"minimum":"","maximum":"","participation":"optional","cardinality":"one","role":"","entityId":1},{"slotIndex":1,"minimum":"","maximum":"","participation":"mandatory","cardinality":"many","role":"","entityId":69}],"id":80}},{"type":"Attribute","details":{"name":"Flight Number","isDerived":false,"isMultivalued":false,"isOptional":false,"isComposite":false,"isUnique":true,"x":638,"y":25,"id":104}},{"type":"Attribute","details":{"name":"Crew ID","isDerived":false,"isMultivalued":false,"isOptional":false,"isComposite":false,"isUnique":true,"x":236,"y":99.5,"id":106}},{"type":"Attribute","details":{"name":"Aircraft ID","isDerived":false,"isMultivalued":false,"isOptional":false,"isComposite":false,"isUnique":true,"x":1361,"y":108.5,"id":108}},{"type":"Attribute","details":{"name":"Gate ID","isDerived":false,"isMultivalued":false,"isOptional":false,"isComposite":false,"isUnique":true,"x":210,"y":588.5,"id":110}},{"type":"Attribute","details":{"name":"Passenger ID","isDerived":false,"isMultivalued":false,"isOptional":false,"isComposite":false,"isUnique":true,"x":1191,"y":209.5,"id":112}},{"type":"Attribute","details":{"name":"Weather ID","isDerived":false,"isMultivalued":false,"isOptional":false,"isComposite":false,"isUnique":true,"x":1222,"y":431.5,"id":114}},{"type":"Entity","details":{"name":"Airport","type":"regular","x":600,"y":575.5,"isDisjointed":true,"isTotalSpecialization":true,"isSubtype":false,"supertypeEntityId":null,"id":118}},{"type":"Attribute","details":{"name":"Airport ID","isDerived":false,"isMultivalued":false,"isOptional":false,"isComposite":false,"isUnique":true,"x":453,"y":579.5,"id":119}},{"type":"Attribute","details":{"name":"Name","isDerived":false,"isMultivalued":false,"isOptional":false,"isComposite":false,"isUnique":false,"x":646,"y":661.5,"id":121}},{"type":"Attribute","details":{"name":"City","isDerived":false,"isMultivalued":false,"isOptional":false,"isComposite":false,"isUnique":false,"x":503,"y":652.5,"id":123}},{"type":"Relationship","details":{"name":"Relationship","isIdentifying":false,"x":369,"y":496,"slots":[{"slotIndex":0,"minimum":"","maximum":"","participation":"mandatory","cardinality":"many","role":"","entityId":27},{"slotIndex":1,"minimum":"","maximum":"","participation":"mandatory","cardinality":"one","role":"","entityId":118}],"id":125}},{"type":"Relationship","details":{"name":"Destination Airport","isIdentifying":false,"x":536,"y":455,"slots":[{"slotIndex":0,"minimum":"","maximum":"","participation":"optional","cardinality":"one","role":"","entityId":118},{"slotIndex":1,"minimum":"","maximum":"","participation":"mandatory","cardinality":"many","role":"","entityId":1}],"id":128}},{"type":"Relationship","details":{"name":"Source Airport","isIdentifying":false,"x":673,"y":457,"slots":[{"slotIndex":0,"minimum":"","maximum":"","participation":"mandatory","cardinality":"one","role":"","entityId":118},{"slotIndex":1,"minimum":"","maximum":"","participation":"mandatory","cardinality":"many","role":"","entityId":1}],"id":131}},{"type":"Relationship","details":{"name":"Departure Gate","isIdentifying":false,"x":374,"y":387,"slots":[{"slotIndex":0,"minimum":"","maximum":"","participation":"mandatory","cardinality":"one","role":"","entityId":27},{"slotIndex":1,"minimum":"","maximum":"","participation":"mandatory","cardinality":"many","role":"","entityId":1}],"id":134}},{"type":"Relationship","details":{"name":"Source Airport","isIdentifying":false,"x":888,"y":459,"slots":[{"slotIndex":0,"minimum":"","maximum":"","participation":"optional","cardinality":"one","role":"","entityId":118},{"slotIndex":1,"minimum":"","maximum":"","participation":"mandatory","cardinality":"many","role":"","entityId":69}],"id":137}},{"type":"Relationship","details":{"name":"Destination Airport","isIdentifying":false,"x":918,"y":604,"slots":[{"slotIndex":0,"minimum":"","maximum":"","participation":"optional","cardinality":"one","role":"","entityId":118},{"slotIndex":1,"minimum":"","maximum":"","participation":"mandatory","cardinality":"many","role":"","entityId":69}],"id":140}}],"connectors":[{"type":"Connector","details":{"id":84},"source":2,"destination":1},{"type":"Connector","details":{"id":85},"source":4,"destination":1},{"type":"Connector","details":{"id":86},"source":6,"destination":1},{"type":"Connector","details":{"id":87},"source":8,"destination":1},{"type":"Connector","details":{"id":88},"source":10,"destination":1},{"type":"Connector","details":{"id":89},"source":15,"destination":14},{"type":"Connector","details":{"id":90},"source":17,"destination":14},{"type":"RelationshipConnector","details":{"slotIndex":0,"id":20},"source":14,"destination":19},{"type":"RelationshipConnector","details":{"slotIndex":1,"id":21},"source":1,"destination":19},{"type":"Connector","details":{"id":91},"source":23,"destination":22},{"type":"Connector","details":{"id":92},"source":25,"destination":22},{"type":"Connector","details":{"id":93},"source":28,"destination":27},{"type":"Connector","details":{"id":94},"source":30,"destination":27},{"type":"RelationshipConnector","details":{"slotIndex":0,"id":33},"source":1,"destination":32},{"type":"RelationshipConnector","details":{"slotIndex":1,"id":34},"source":22,"destination":32},{"type":"RelationshipConnector","details":{"slotIndex":0,"id":36},"source":1,"destination":35},{"type":"RelationshipConnector","details":{"slotIndex":1,"id":37},"source":27,"destination":35},{"type":"Connector","details":{"id":95},"source":42,"destination":41},{"type":"Connector","details":{"id":96},"source":44,"destination":41},{"type":"Connector","details":{"id":97},"source":46,"destination":41},{"type":"Connector","details":{"id":98},"source":48,"destination":41},{"type":"RelationshipConnector","details":{"slotIndex":0,"id":67},"source":1,"destination":66},{"type":"RelationshipConnector","details":{"slotIndex":1,"id":68},"source":41,"destination":66},{"type":"Connector","details":{"id":99},"source":70,"destination":69},{"type":"Connector","details":{"id":100},"source":72,"destination":69},{"type":"Connector","details":{"id":101},"source":74,"destination":69},{"type":"Connector","details":{"id":103},"source":78,"destination":69},{"type":"RelationshipConnector","details":{"slotIndex":0,"id":81},"source":1,"destination":80},{"type":"RelationshipConnector","details":{"slotIndex":1,"id":82},"source":69,"destination":80},{"type":"Connector","details":{"id":105},"source":104,"destination":1},{"type":"Connector","details":{"id":107},"source":106,"destination":22},{"type":"Connector","details":{"id":109},"source":108,"destination":14},{"type":"Connector","details":{"id":111},"source":110,"destination":27},{"type":"Connector","details":{"id":113},"source":112,"destination":41},{"type":"Connector","details":{"id":115},"source":114,"destination":69},{"type":"Connector","details":{"id":120},"source":119,"destination":118},{"type":"Connector","details":{"id":122},"source":121,"destination":118},{"type":"Connector","details":{"id":124},"source":123,"destination":118},{"type":"RelationshipConnector","details":{"slotIndex":0,"id":126},"source":27,"destination":125},{"type":"RelationshipConnector","details":{"slotIndex":1,"id":127},"source":118,"destination":125},{"type":"RelationshipConnector","details":{"slotIndex":0,"id":129},"source":118,"destination":128},{"type":"RelationshipConnector","details":{"slotIndex":1,"id":130},"source":1,"destination":128},{"type":"RelationshipConnector","details":{"slotIndex":0,"id":132},"source":118,"destination":131},{"type":"RelationshipConnector","details":{"slotIndex":1,"id":133},"source":1,"destination":131},{"type":"RelationshipConnector","details":{"slotIndex":0,"id":135},"source":27,"destination":134},{"type":"RelationshipConnector","details":{"slotIndex":1,"id":136},"source":1,"destination":134},{"type":"RelationshipConnector","details":{"slotIndex":0,"id":138},"source":118,"destination":137},{"type":"RelationshipConnector","details":{"slotIndex":1,"id":139},"source":69,"destination":137},{"type":"RelationshipConnector","details":{"slotIndex":0,"id":141},"source":118,"destination":140},{"type":"RelationshipConnector","details":{"slotIndex":1,"id":142},"source":69,"destination":140}],"width":3000,"height":1500}"""

# %%
dat = json.loads(data)

# %%
dat = dat['shapes']

# %%
dat
# Out:
# [{'type': 'Entity',
#   'details': {'name': 'Flight',
#    'type': 'regular',
#    'x': 624,
#    'y': 128,
#    'isDisjointed': True,
#    'isTotalSpecialization': True,
#    'isSubtype': False,
#    'supertypeEntityId': None,
#    'id': 1}},
#  {'type': 'Attribute',
#   'details': {'name': 'Source Airport ID',
#    'isDerived': False,
#    'isMultivalued': False,
#    'isOptional': False,
#    'isComposite': False,
#    'isUnique': False,
#    'x': 376,
#    'y': 98,
#    'id': 2}},
#  {'type': 'Attribute',
#   'details': {'name': 'Destination Airport ID',
#    'isDerived': False,
#    'isMultivalued': False,
#    'isOptional': False,
#    'isComposite': False,
#    'isUnique': False,
#    'x': 422,
#    'y': 43,
#    'id': 4}},
#  {'type': 'Attribute',
#   'details': {'name': 'Departure Time',
#    'isDerived': False,
#    'isMultivalued': False,
#    'isOptional': False,
#    'isComposite': False,
#    'isUnique': False,
#    'x': 529,
#    'y': 31,
#    'id': 6}},
# ...

# %%
with open('erd.json', 'w') as f:
    json.dump(dat, f, indent=4)
